# %%
#importing basics libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Q1. Load the flight price dataset and examine its dimensions. How many rows and columns does the
# dataset have?

# %%
df=pd.read_excel("flight_price.xlsx")
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
df.shape
# Out:
# (10683, 11)

# %%
print('No. of rows:',df.shape[0])
print('No. of cols:',df.shape[1])
# Out:
# No. of rows: 10683
# No. of cols: 11

# %% [markdown]
# Q2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the
# distribution.

# %%
sns.histplot(data=df,x=df['Price'])
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Count'>

# %% [markdown]
# Q3. What is the range of prices in the dataset? What is the minimum and maximum price?

# %%
df['Price'].describe()
# Out:
# count    10683.000000
# mean      9087.064121
# std       4611.359167
# min       1759.000000
# 25%       5277.000000
# 50%       8372.000000
# 75%      12373.000000
# max      79512.000000
# Name: Price, dtype: float64

# %%
print('Range:',df['Price'].max()-df['Price'].min())
print('Max:',df['Price'].max())
print('Min:',df['Price'].min())
# Out:
# Range: 77753
# Max: 79512
# Min: 1759

# %% [markdown]
# Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different
# airlines.

# %%
plt.figure(figsize=(12,10))
sns.boxplot(x=df['Airline'],y=df['Price'])
plt.xticks(rotation=90)
plt.title("Flight prices of diff airlines")
plt.show()

# %% [markdown]
# Q5. Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how
# they may impact your analysis.

# %%
plt.figure(figsize=(12,10))
sns.boxplot(y=df['Price'])
plt.show()

# %%
df['Price'].describe()
# Out:
# count    10683.000000
# mean      9087.064121
# std       4611.359167
# min       1759.000000
# 25%       5277.000000
# 50%       8372.000000
# 75%      12373.000000
# max      79512.000000
# Name: Price, dtype: float64

# %%
IQR = 12373-5277.000000
lower_limit = 5277.000000 - 1.5*IQR
upper_limit = 12373.000000 + 1.5*IQR
print(upper_limit)
print(lower_limit)
# Out:
# 23017.0
# -5367.0

# %%
df_outlier=df[df['Price']>23017.0]
df_outlier['Price']
# Out:
# 123      27430
# 396      36983
# 486      26890
# 510      26890
# 597      25139
#          ...
# 10353    24210
# 10364    57209
# 10383    26890
# 10439    31825
# 10511    26480
# Name: Price, Length: 94, dtype: int64

# %%
df_outlier['Price'].value_counts()
# Out:
# 26890    24
# 25735    10
# 27992     9
# 31825     6
# 54826     3
# 27210     2
# 25430     2
# 36235     2
# 27430     1
# 23528     1
# 29528     1
# 34503     1
# 23170     1
# 24528     1
# 34608     1
# 25703     1
# 52285     1
# 27282     1
# 34273     1
# 24017     1
# 31945     1
# 24318     1
# 23677     1
# 24210     1
# 57209     1
# 46490     1
# 23267     1
# 28322     1
# 31783     1
# 25139     1
# 52229     1
# 26743     1
# 23583     1
# 23533     1
# 24115     1
# 35185     1
# 23843     1
# 79512     1
# 28097     1
# 26092     1
# 25913     1
# 36983     1
# 62427     1
# 26480     1
# Name: Price, dtype: int64

# %% [markdown]
# Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset
# to identify the peak travel season. What features would you analyze to identify the peak season, and how
# would you present your findings to your boss?

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df['Date_of_Journey']
# Out:
# 0        24/03/2019
# 1         1/05/2019
# 2         9/06/2019
# 3        12/05/2019
# 4        01/03/2019
#             ...
# 10678     9/04/2019
# 10679    27/04/2019
# 10680    27/04/2019
# 10681    01/03/2019
# 10682     9/05/2019
# Name: Date_of_Journey, Length: 10683, dtype: object

# %%
df['Month']=df['Date_of_Journey'].str.split('/').str[1]
df['Month']=df['Month'].astype(int)

# %%
df['Month']
# Out:
# 0        3
# 1        5
# 2        6
# 3        5
# 4        3
#         ..
# 10678    4
# 10679    4
# 10680    4
# 10681    3
# 10682    5
# Name: Month, Length: 10683, dtype: int64

# %%
df["Date_of_Journey"] = pd.to_datetime(df["Date_of_Journey"])
# Out:
# /tmp/ipykernel_4178/1954500797.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df["Date_of_Journey"] = pd.to_datetime(df["Date_of_Journey"])

# %%
#extracting month  data separately for analysis
df["Month"] = df["Date_of_Journey"].dt.month_name()

# %%
#preparing data for getting the peak season by month 
data = pd.DataFrame(df.Month.value_counts())
data.rename(columns={"Month":"Count"},inplace=True)

# %%
#plotting 
plt.figure(figsize=(15,6))
sns.barplot(data=data,x=data.index,y=data.Count)
plt.xlabel("Months")
plt.title("No of fligths per month")
# Out:
# Text(0.5, 1.0, 'No of fligths per month')

# %% [markdown]
# Q7. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight
# Price dataset to identify any trends in flight prices. What features would you analyze to identify these
# trends, and what visualizations would you use to present your findings to your team?

# %% [markdown]
# No. of flights per month

# %%
#plotting 
data = pd.DataFrame(df.Month.value_counts())
data.rename(columns={"Month":"Count"},inplace=True)
plt.figure(figsize=(15,6))
sns.barplot(data=data,x=data.index,y=data.Count)
plt.xlabel("Months")
plt.title("No of fligths per month")
# Out:
# Text(0.5, 1.0, 'No of fligths per month')

# %%
# Source wise avg. flight prices

# %%
df1=pd.DataFrame(df['Price'].groupby(df["Source"]).mean())

# %%
plt.figure(figsize=(15,6))
sns.barplot(data=df1,y=df1["Price"],x=df1.index)
plt.xlabel("Sources")
plt.title("Avg.Price according to source city")
# Out:
# Text(0.5, 1.0, 'Avg.Price according to source city')

# %%
df2=pd.DataFrame(df['Price'].groupby(df["Airline"]).mean())

# %%
plt.figure(figsize=(15,6))
sns.lineplot(data=df2,y=df2["Price"],x=df2.index)
plt.xlabel("Sources")
plt.xticks(rotation=90)
plt.title("Avg.Price of Airlines")
# Out:
# Text(0.5, 1.0, 'Avg.Price of Airlines')

# %%
df3=pd.DataFrame(df['Price'].groupby(df["Destination"]).mean())
plt.figure(figsize=(15,6))
sns.barplot(data=df3,y=df3["Price"],x=df3.index)
plt.xlabel("Destination")
plt.title("Avg.Price according to destination city")
# Out:
# Text(0.5, 1.0, 'Avg.Price according to destination city')

# %% [markdown]
# Q8. You are a data scientist working for an airline company, and you have been asked to analyze the
# Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to
# identify these factors, and how would you present your findings to the management team?

# %% [markdown]
# 1. Airlines
# The price range is similar for all the airlines.
# Business is more expensive as expected. Premium economy especially of Vistara is more expensive than most airlines.
# 2. Source city
# Flights originating from Delhi are more expensive compared with other cities while Chennai average prices are the lowest.
# 3. Destination city
# Flights landing at New Delhi are more expensive compared with other cities while Kolkata average prices are the lowest.

# %% [markdown]
# Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns does
# the dataset have?

# %%
df = pd.read_csv("https://raw.githubusercontent.com/jasonchang0/kaggle-google-apps/master/google-play-store-apps/googleplaystore.csv")
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.shape
# Out:
# (10841, 13)

# %%
print('No. of rows:',df.shape[0])
print('No. of cols:',df.shape[1])
# Out:
# No. of rows: 10841
# No. of cols: 13

# %% [markdown]
# Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of different
# app categories.

# %%
sns.boxplot(y=df['Rating'],x=df['Category'])
plt.xticks(rotation=90)
plt.ylim(1,5)
plt.figure(figsize=(25,1))

# %% [markdown]
# Q11. Are there any missing values in the dataset? Identify any missing values and describe how they may
# impact your analysis.

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# There are 1474 missing values in ratings. If this is not handled before feeding this data into the model then it will lead to inaccurate estimates. Since Ratings is numerical data the missing values may result in dragging the mean to one side resulting in skeweness and also this may lead to false positive outliers

# %% [markdown]
# Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualize
# the relationship.

# %%
#cleaning the size column and converting it into uniform units
#defining a function to convert the Size column
def col_clean(i):
    if i.endswith("M"):
        return float(i.split("M")[0])
    elif i.endswith("k"):
        return float(i.split("k")[0])/1000
    else:
        if i == 'Varies with device':
            return (np.nan)

# %%
#converting the size column
df.Size = df.Size.apply(col_clean)
#filling missing values in Size column with mean
df.Size.fillna(df.Size.mean(),inplace=True)

# %%
#cleaning the rating column
df.Rating = df.Rating.replace(19,1.9)
#filling the missing values of Ratings
df.Rating.fillna(df.Rating.mean(),inplace=True)

# %%
sns.scatterplot(data=df,x="Size",y="Rating")
# Out:
# <AxesSubplot: xlabel='Size', ylabel='Rating'>

# %% [markdown]
# Apps with large size have higher rating

# %% [markdown]
# Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.

# %%
df['Price']=df['Price'].str.replace('$','')
# Out:
# /tmp/ipykernel_4178/3004727282.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Price']=df['Price'].str.replace('$','')

# %%
df['Price']=df['Price'].str.replace('Everyone','0')

# %%
df['Price']=df['Price'].astype(float)

# %%
df['Type']=df['Type'].replace('0','Free')

# %%
df.Type.fillna(df.Type.mode(),inplace=True)

# %%
data = df.groupby("Type")["Price"].mean()

# %%
#plotting the bar chart
plt.figure(figsize=(7,4))
data.plot.bar()
plt.ylabel("Average Price")
plt.title("Average price based on App type")
plt.show()

# %% [markdown]
# Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps
# with the highest number of installs.

# %%
#cleaning the installs column
df.Installs = df.Installs.str.strip("+").str.replace(",","").str.replace("Free","0").astype(int)
#Top 10 most popular Apps with frequency of installs
df[["App","Installs"]].sort_values("Installs",ascending=False)[:10]
# Out:
#                                            App    Installs
# 3896                            Subway Surfers  1000000000
# 3943                                  Facebook  1000000000
# 335   Messenger – Text and Video Chat for Free  1000000000
# 3523                              Google Drive  1000000000
# 3565                              Google Drive  1000000000
# 2884                             Google Photos  1000000000
# 3665                                   YouTube  1000000000
# 2853                             Google Photos  1000000000
# 4234             Skype - free IM & video calls  1000000000
# 3687                   Google Play Movies & TV  1000000000

# %% [markdown]
# Q15. A company wants to launch a new app on the Google Playstore and has asked you to analyze the
# Google Playstore dataset to identify the most popular app categories. How would you approach this
# task, and what features would you analyze to make recommendations to the company?

# %%
df['Installs'].astype(float)
# Out:
# 0           10000.0
# 1          500000.0
# 2         5000000.0
# 3        50000000.0
# 4          100000.0
#             ...
# 10836        5000.0
# 10837         100.0
# 10838        1000.0
# 10839        1000.0
# 10840    10000000.0
# Name: Installs, Length: 10841, dtype: float64

# %%
# Take avg install and rating of all app categories
pd.options.display.float_format = '{:.1f}'.format
df2=df['Rating'].groupby(df['Category']).mean()

df3=df['Installs'].groupby(df['Category']).mean()
df3.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 34 entries, 1.9 to WEATHER
# Series name: Installs
# Non-Null Count  Dtype
# --------------  -----
# 34 non-null     float64
# dtypes: float64(1)
# memory usage: 544.0+ bytes

# %%
df4=pd.concat([df2,df3],axis=1)

# %%
df4=df4.drop('1.9')

# %%
plt.figure(figsize=(10,7))

sns.scatterplot(data=df4,x=df4['Installs'],y=df4["Rating"],hue=df4.index)
plt.title("Rating and Installs of apps according to category")
plt.xlim(0.0,6000000.0)
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.show()

# %% [markdown]
# Q16. A mobile app development company wants to analyze the Google Playstore dataset to identify the
# most successful app developers. What features would you analyze to make recommendations to the
# company, and what data visualizations would you use to present your findings?

# %%
data=df[['App','Installs']].sort_values("Installs",ascending=False)[0:20]
data
# Out:
#                                            App    Installs
# 3896                            Subway Surfers  1000000000
# 3943                                  Facebook  1000000000
# 335   Messenger – Text and Video Chat for Free  1000000000
# 3523                              Google Drive  1000000000
# 3565                              Google Drive  1000000000
# 2884                             Google Photos  1000000000
# 3665                                   YouTube  1000000000
# 2853                             Google Photos  1000000000
# 4234             Skype - free IM & video calls  1000000000
# 3687                   Google Play Movies & TV  1000000000
# 2808                             Google Photos  1000000000
# 4170                              Google Drive  1000000000
# 4153                                  Hangouts  1000000000
# 4150                                    Google  1000000000
# 152                          Google Play Books  1000000000
# ...

# %%
plt.pie(data=data,x=data['Installs'],labels=data.App,autopct='%.0f%%')
plt.show()

# %% [markdown]
# Q17. A marketing research firm wants to analyze the Google Playstore dataset to identify the best time to
# launch a new app. What features would you analyze to make recommendations to the company, and
# what data visualizations would you use to present your findings?

# %% [markdown]
# To analyze the Google Playstore dataset and identify the best time to launch a new app, we could analyze the following features:
#
# Category: We could examine the most popular app categories and determine which categories have the highest number of new apps being released.
#
# Release date: We could examine the release dates for existing apps and determine which months or days of the week have the highest number of new app releases.
#
# Installs: We could examine the number of installs for existing apps and determine which months or days of the week have the highest level of user engagement.
#
# To present our findings, we could use data visualizations such as line charts or bar charts to show the distribution of app releases by month or day of the week. We could also use scatter plots or line charts to show the relationship between app installs and release dates. Additionally, we could use regression analysis to determine if there is a statistically significant relationship between release date and app installs.
